# %%
# fake_dataset = [
#     ["f", "c", "a", "m", "p"],
#     ["f", "c", "a", "b", "m"],
#     ["f", "b"],
#     ["c", "b", "p"],
#     ["f", "c", "a", "m", "p"]
# ]

fake_dataset = [
    ["milk", "bread", "beer"],
    ["bread", "coffee"],
    ["bread", "egg"],
    ["milk", "bread", "coffee"],
    ["milk", "egg"],
    ["bread", "egg"],
    ["milk", "egg"],
    ["milk", "bread", "egg", "beer"],
    ["milk", "bread", "egg"],
]


class node:
    def __init__(self, item, count=1):
        self.item = item
        self.count = count
        self.parent = None
        self.children = list()

    def __str__(self):
        return f'id={id(self)}, item={self.item}, count={self.count}, parent={self.parent.item}, children_num={len(self.children)}'


# nx3 list, [0]=Customer ID, [1]=Transaction ID, [2] Item ID
def load_data(filename):
    dataset = list()
    with open(filename) as f:
        tid = 1  # transaction id
        temp_item = list()
        for i in f.readlines():
            item = i.replace("\n", "").split(",")
            if tid < int(item[1]):
                tid = int(item[1])
                dataset.append(temp_item.copy())
                temp_item.clear()
            temp_item.append(item[2])
    return dataset


# 掃描全dataset一次，統計每個item出現的次數
def first_scan(dataset):
    weights = dict()
    for transaction in dataset:
        for item in transaction:
            if weights.get(item):
                weights[item] += 1
            else:
                weights[item] = 1
    return weights


# 排序transaction內的item，並刪除小於最小最小支持度的item
def reorder(dataset, weights, min_sup):
    for tid in range(len(dataset)):
        dataset[tid] = [item for item in dataset[tid] if weights[item] >= min_sup]
        dataset[tid].sort(key=lambda x: weights[x], reverse=True)
        

# 建立FP tree，傳root代表update tree
def create_tree(dataset, root=node(None), count=1):
    pre_node = root
    for transaction in dataset:
        for item in transaction:
            for c in pre_node.children:
                if item == c.item:
                    c.count += count
                    pre_node = c
                    break
            else:  # new node
                print("new node:", item, "parent:", pre_node.item)
                current_node = node(item, count)
                current_node.parent = pre_node
                pre_node.children.append(current_node)
                pre_node = current_node
        pre_node = root
        print("========================================================")
        show_tree(root)  # current tree after insert one transaction
        print("========================================================")
    return root


# header_table key=item, value=list of node
def create_header_table(node, header_table=dict()):
    if node.item != None:  # skip root node
        # create header table link
        if header_table.get(node.item):
            header_table[node.item].append(node)
        else:
            header_table[node.item] = [node]
    for c in node.children:
        create_header_table(c, header_table)
    return header_table


# 用header_table的list找所有的parent path
def find_path(header_table, target):
    path_dict = dict()
    for k, v in header_table.items():
        if k == target:
            for node in v:
                path = list()
                parent = node.parent
                while parent.item != None:  # get parent
                    path.append(parent.item)
                    parent = parent.parent
                path.reverse()
                if len(path) != 0:  # first child of root
                    path_dict[tuple(path)] = node.count
            return path_dict


# 建立combination tree
def mine_tree(path_dict):
    # sort dict by value
    combination_dataset, counts = zip(*[(dict[0], dict[1])
                                      for dict in sorted(path_dict.items(), key=lambda x:x[1], reverse=True)])
    print("@@@combination_dataset@@@", combination_dataset)
    print("@@@counts@@@", counts)

    root = node(None)
    for transaction, count in zip(combination_dataset, counts):
        root = create_tree([transaction], root=root, count=count)
    print("@@@Combination FP tree@@@")
    show_tree(root)
    return root

def del_bad_node(node, min_sup):
    if node.item != None:  # skip root node
        pass
    for c in node.children[::-1]:
        if c.count<min_sup:
            node.children.remove(c)
        else:
            del_bad_node(c, min_sup)


def find_freq_item_set(node, freq_item_set):
    # if node.item==None or node.parent.item==None:
    #     print("清空", node.item)
    #     freq_item_set = dict()
    for c in node.children:
        new_freq_item_set = freq_item_set.copy()
        if c.parent.item==None:
            print("清空")
            new_freq_item_set = dict()
        print("不選", c.item, ", parent", c.parent.item)
        find_freq_item_set(c, new_freq_item_set)
        print("選", c.item, c.parent.item)
        print("有前", new_freq_item_set)
        if new_freq_item_set.get(c.item):
            new_freq_item_set[c.item]+=c.count
        else:
            new_freq_item_set[c.item]=c.count
        print("有後", new_freq_item_set)
        find_freq_item_set(c, new_freq_item_set)
        print("freq_item_set", new_freq_item_set)

        s = frozenset()
        temp_min = 999
        for k, v in new_freq_item_set.items():
            s = s.union(frozenset((k,)))
            v = min(temp_min, v)
        if foo_dict.get(s):
            foo_dict[s]+=v
        else:
            foo_dict[s]=v
        


def show_tree(node):
    if node.item != None:  # skip root node
        print(node)
    for c in node.children:
        show_tree(c)


def show_header_table(header_table):
    for k, v in header_table.items():
        print("item:", k)
        for node in v:
            print(id(node))

# %%
# fake_dataset = input_data
min_sup = 2
weights = first_scan(fake_dataset)
print(weights)
print("before ordering:", fake_dataset)
reorder(fake_dataset, weights, min_sup)
print("after ordering:", fake_dataset)

root = create_tree(fake_dataset)
print("@@@FP tree@@@")
show_tree(root)

header_table = create_header_table(root)
print("@@@header table@@@")
show_header_table(header_table)

# freq_itemset = list()
print("@@@path@@@")
ans = list()
for header in header_table:
    path_dict = find_path(header_table, header)
    for k, v in path_dict.items():
        print(k, v)
    if len(path_dict)>0:
        root = mine_tree(path_dict)
        del_bad_node(root, min_sup)
        print("@@@after remove bad node@@@")
        show_tree(root)
        
        foo = dict()
        foo_dict = dict()
        find_freq_item_set(root, foo)
        print("@@@我到底在幹嘛阿@@@")
        for k, v in foo_dict.items():
            ans.append([str(set(k.union(frozenset((header,))))), v])
            print(ans[-1])
# Out:
# {'milk': 6, 'bread': 7, 'beer': 2, 'coffee': 2, 'egg': 6}
# before ordering: [['milk', 'bread', 'beer'], ['bread', 'coffee'], ['bread', 'egg'], ['milk', 'bread', 'coffee'], ['milk', 'egg'], ['bread', 'egg'], ['milk', 'egg'], ['milk', 'bread', 'egg', 'beer'], ['milk', 'bread', 'egg']]
# after ordering: [['bread', 'milk', 'beer'], ['bread', 'coffee'], ['bread', 'egg'], ['bread', 'milk', 'coffee'], ['milk', 'egg'], ['bread', 'egg'], ['milk', 'egg'], ['bread', 'milk', 'egg', 'beer'], ['bread', 'milk', 'egg']]
# new node: bread parent: None
# new node: milk parent: bread
# new node: beer parent: milk
# ========================================================
# id=2460648983904, item=bread, count=1, parent=None, children_num=1
# id=2460658404896, item=milk, count=1, parent=bread, children_num=1
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# ========================================================
# new node: coffee parent: bread
# ========================================================
# id=2460648983904, item=bread, count=2, parent=None, children_num=2
# id=2460658404896, item=milk, count=1, parent=bread, children_num=1
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# ========================================================
# new node: egg parent: bread
# ========================================================
# id=2460648983904, item=bread, count=3, parent=None, children_num=3
# id=2460658404896, item=milk, count=1, parent=bread, children_num=1
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=1, parent=bread, children_num=0
# ========================================================
# new node: coffee parent: milk
# ========================================================
# id=2460648983904, item=bread, count=4, parent=None, children_num=3
# id=2460658404896, item=milk, count=2, parent=bread, children_num=2
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=1, parent=bread, children_num=0
# ========================================================
# new node: milk parent: None
# new node: egg parent: milk
# ========================================================
# id=2460648983904, item=bread, count=4, parent=None, children_num=3
# id=2460658404896, item=milk, count=2, parent=bread, children_num=2
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=1, parent=bread, children_num=0
# id=2460658134512, item=milk, count=1, parent=None, children_num=1
# id=2460658133360, item=egg, count=1, parent=milk, children_num=0
# ========================================================
# ========================================================
# id=2460648983904, item=bread, count=5, parent=None, children_num=3
# id=2460658404896, item=milk, count=2, parent=bread, children_num=2
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=2, parent=bread, children_num=0
# id=2460658134512, item=milk, count=1, parent=None, children_num=1
# id=2460658133360, item=egg, count=1, parent=milk, children_num=0
# ========================================================
# ========================================================
# id=2460648983904, item=bread, count=5, parent=None, children_num=3
# id=2460658404896, item=milk, count=2, parent=bread, children_num=2
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=2, parent=bread, children_num=0
# id=2460658134512, item=milk, count=2, parent=None, children_num=1
# id=2460658133360, item=egg, count=2, parent=milk, children_num=0
# ========================================================
# new node: egg parent: milk
# new node: beer parent: egg
# ========================================================
# id=2460648983904, item=bread, count=6, parent=None, children_num=3
# id=2460658404896, item=milk, count=3, parent=bread, children_num=3
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658430544, item=egg, count=1, parent=milk, children_num=1
# id=2460658433280, item=beer, count=1, parent=egg, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=2, parent=bread, children_num=0
# id=2460658134512, item=milk, count=2, parent=None, children_num=1
# id=2460658133360, item=egg, count=2, parent=milk, children_num=0
# ========================================================
# ========================================================
# id=2460648983904, item=bread, count=7, parent=None, children_num=3
# id=2460658404896, item=milk, count=4, parent=bread, children_num=3
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658430544, item=egg, count=2, parent=milk, children_num=1
# id=2460658433280, item=beer, count=1, parent=egg, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=2, parent=bread, children_num=0
# id=2460658134512, item=milk, count=2, parent=None, children_num=1
# id=2460658133360, item=egg, count=2, parent=milk, children_num=0
# ========================================================
# @@@FP tree@@@
# id=2460648983904, item=bread, count=7, parent=None, children_num=3
# id=2460658404896, item=milk, count=4, parent=bread, children_num=3
# id=2460658401776, item=beer, count=1, parent=milk, children_num=0
# id=2460646003568, item=coffee, count=1, parent=milk, children_num=0
# id=2460658430544, item=egg, count=2, parent=milk, children_num=1
# id=2460658433280, item=beer, count=1, parent=egg, children_num=0
# id=2460658448320, item=coffee, count=1, parent=bread, children_num=0
# id=2460658450048, item=egg, count=2, parent=bread, children_num=0
# id=2460658134512, item=milk, count=2, parent=None, children_num=1
# id=2460658133360, item=egg, count=2, parent=milk, children_num=0
# @@@header table@@@
# item: bread
# 2460648983904
# item: milk
# 2460658404896
# 2460658134512
# item: beer
# 2460658401776
# 2460658433280
# item: coffee
# 2460646003568
# 2460658448320
# item: egg
# 2460658430544
# 2460658450048
# 2460658133360
# @@@path@@@
# ('bread',) 4
# @@@combination_dataset@@@ (('bread',),)
# @@@counts@@@ (4,)
# new node: bread parent: None
# ========================================================
# id=2460646848688, item=bread, count=4, parent=None, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2460646848688, item=bread, count=4, parent=None, children_num=0
# @@@after remove bad node@@@
# id=2460646848688, item=bread, count=4, parent=None, children_num=0
# 清空
# 不選 bread , parent None
# 選 bread None
# 有前 {}
# 有後 {'bread': 4}
# freq_item_set {'bread': 4}
# @@@我到底在幹嘛阿@@@
# ["{'milk', 'bread'}", 4]
# ('bread', 'milk') 1
# ('bread', 'milk', 'egg') 1
# @@@combination_dataset@@@ (('bread', 'milk'), ('bread', 'milk', 'egg'))
# @@@counts@@@ (1, 1)
# new node: bread parent: None
# new node: milk parent: bread
# ========================================================
# id=2460644134096, item=bread, count=1, parent=None, children_num=1
# id=2460658433904, item=milk, count=1, parent=bread, children_num=0
# ========================================================
# new node: egg parent: milk
# ========================================================
# id=2460644134096, item=bread, count=2, parent=None, children_num=1
# id=2460658433904, item=milk, count=2, parent=bread, children_num=1
# id=2460644132656, item=egg, count=1, parent=milk, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2460644134096, item=bread, count=2, parent=None, children_num=1
# id=2460658433904, item=milk, count=2, parent=bread, children_num=1
# id=2460644132656, item=egg, count=1, parent=milk, children_num=0
# @@@after remove bad node@@@
# id=2460644134096, item=bread, count=2, parent=None, children_num=1
# id=2460658433904, item=milk, count=2, parent=bread, children_num=0
# 清空
# 不選 bread , parent None
# 不選 milk , parent bread
# 選 milk bread
# 有前 {}
# 有後 {'milk': 2}
# freq_item_set {'milk': 2}
# 選 bread None
# 有前 {}
# 有後 {'bread': 2}
# 不選 milk , parent bread
# 選 milk bread
# 有前 {'bread': 2}
# 有後 {'bread': 2, 'milk': 2}
# freq_item_set {'bread': 2, 'milk': 2}
# freq_item_set {'bread': 2}
# @@@我到底在幹嘛阿@@@
# ["{'beer', 'milk'}", 2]
# ["{'beer', 'milk', 'bread'}", 2]
# ["{'beer', 'bread'}", 2]
# ('bread', 'milk') 1
# ('bread',) 1
# @@@combination_dataset@@@ (('bread', 'milk'), ('bread',))
# @@@counts@@@ (1, 1)
# new node: bread parent: None
# new node: milk parent: bread
# ========================================================
# id=2460658431792, item=bread, count=1, parent=None, children_num=1
# id=2460658433664, item=milk, count=1, parent=bread, children_num=0
# ========================================================
# ========================================================
# id=2460658431792, item=bread, count=2, parent=None, children_num=1
# id=2460658433664, item=milk, count=1, parent=bread, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2460658431792, item=bread, count=2, parent=None, children_num=1
# id=2460658433664, item=milk, count=1, parent=bread, children_num=0
# @@@after remove bad node@@@
# id=2460658431792, item=bread, count=2, parent=None, children_num=0
# 清空
# 不選 bread , parent None
# 選 bread None
# 有前 {}
# 有後 {'bread': 2}
# freq_item_set {'bread': 2}
# @@@我到底在幹嘛阿@@@
# ["{'coffee', 'bread'}", 2]
# ('bread', 'milk') 2
# ('bread',) 2
# ('milk',) 2
# @@@combination_dataset@@@ (('bread', 'milk'), ('bread',), ('milk',))
# @@@counts@@@ (2, 2, 2)
# new node: bread parent: None
# new node: milk parent: bread
# ========================================================
# id=2460658430736, item=bread, count=2, parent=None, children_num=1
# id=2460658430592, item=milk, count=2, parent=bread, children_num=0
# ========================================================
# ========================================================
# id=2460658430736, item=bread, count=4, parent=None, children_num=1
# id=2460658430592, item=milk, count=2, parent=bread, children_num=0
# ========================================================
# new node: milk parent: None
# ========================================================
# id=2460658430736, item=bread, count=4, parent=None, children_num=1
# id=2460658430592, item=milk, count=2, parent=bread, children_num=0
# id=2460658237792, item=milk, count=2, parent=None, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2460658430736, item=bread, count=4, parent=None, children_num=1
# id=2460658430592, item=milk, count=2, parent=bread, children_num=0
# id=2460658237792, item=milk, count=2, parent=None, children_num=0
# @@@after remove bad node@@@
# id=2460658430736, item=bread, count=4, parent=None, children_num=1
# id=2460658430592, item=milk, count=2, parent=bread, children_num=0
# id=2460658237792, item=milk, count=2, parent=None, children_num=0
# 清空
# 不選 bread , parent None
# 不選 milk , parent bread
# 選 milk bread
# 有前 {}
# 有後 {'milk': 2}
# freq_item_set {'milk': 2}
# 選 bread None
# 有前 {}
# 有後 {'bread': 4}
# 不選 milk , parent bread
# 選 milk bread
# 有前 {'bread': 4}
# 有後 {'bread': 4, 'milk': 2}
# freq_item_set {'bread': 4, 'milk': 2}
# freq_item_set {'bread': 4}
# 清空
# 不選 milk , parent None
# 選 milk None
# 有前 {}
# 有後 {'milk': 2}
# freq_item_set {'milk': 2}
# @@@我到底在幹嘛阿@@@
# ["{'egg', 'milk'}", 4]
# ["{'egg', 'milk', 'bread'}", 2]
# ["{'egg', 'bread'}", 4]

# %%
root=node(None)
a=node("A",5)
b=node("B",3)
b2=node("B",3)
c=node("C",2)
d=node("D",2)
e=node("E",2)
e2=node("E",2)
root.children.append(a)
a.parent=root
a.children.extend([b, c])
b.parent=a
c.parent=a
b.children.append(e)
c.children.append(b2)
b2.children.append(e2)
b2.parent=c
e.parent=b
e2.parent=b2
header_table = create_header_table(root)
show_tree(root)
show_header_table(header_table)


min_sup=2
# Out:
# id=2405144809328, item=A, count=5, parent=None, children_num=2
# id=2405144807792, item=B, count=3, parent=A, children_num=1
# id=2405144806784, item=E, count=2, parent=B, children_num=0
# id=2405144807696, item=C, count=2, parent=A, children_num=1
# id=2405144809280, item=B, count=3, parent=C, children_num=1
# id=2405144805728, item=E, count=2, parent=B, children_num=0
# item: A
# 2405144809328
# item: B
# 2405144807792
# 2405144809280
# item: E
# 2405144806784
# 2405144805728
# item: C
# 2405144807696

# %%
print("@@@path@@@")
ans = list()
for header in header_table:
    print("item", header)
    path_dict = find_path(header_table, header)
    for k, v in path_dict.items():
        print(k, v)
    if len(path_dict)>0:
        root = mine_tree(path_dict)
        del_bad_node(root, min_sup)
        print("@@@after remove bad node@@@")
        show_tree(root)
        
        foo = dict()
        foo_dict = dict()
        find_freq_item_set(root, foo)
        print("@@@我到底在幹嘛阿@@@")
        for k, v in foo_dict.items():
            ans.append([str(set(k.union(frozenset((header,))))), v])
            print(ans[-1])
# Out:
# @@@path@@@
# item A
# item B
# ('A',) 3
# ('A', 'C') 3
# @@@combination_dataset@@@ (('A',), ('A', 'C'))
# @@@counts@@@ (3, 3)
# new node: A parent: None
# ========================================================
# id=2405145499392, item=A, count=3, parent=None, children_num=0
# ========================================================
# new node: C parent: A
# ========================================================
# id=2405145499392, item=A, count=6, parent=None, children_num=1
# id=2405144677536, item=C, count=3, parent=A, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2405145499392, item=A, count=6, parent=None, children_num=1
# id=2405144677536, item=C, count=3, parent=A, children_num=0
# @@@after remove bad node@@@
# id=2405145499392, item=A, count=6, parent=None, children_num=1
# id=2405144677536, item=C, count=3, parent=A, children_num=0
# 清空
# 不選 A , parent None
# 不選 C , parent A
# 選 C A
# 有前 {}
# 有後 {'C': 3}
# freq_item_set {'C': 3}
# 選 A None
# 有前 {}
# 有後 {'A': 6}
# 不選 C , parent A
# 選 C A
# 有前 {'A': 6}
# 有後 {'A': 6, 'C': 3}
# freq_item_set {'A': 6, 'C': 3}
# freq_item_set {'A': 6}
# @@@我到底在幹嘛阿@@@
# ["{'C', 'B'}", 3]
# ["{'A', 'C', 'B'}", 3]
# ["{'A', 'B'}", 6]
# item E
# ('A', 'B') 2
# ('A', 'C', 'B') 2
# @@@combination_dataset@@@ (('A', 'B'), ('A', 'C', 'B'))
# @@@counts@@@ (2, 2)
# new node: A parent: None
# new node: B parent: A
# ========================================================
# id=2405144677344, item=A, count=2, parent=None, children_num=1
# id=2405144678112, item=B, count=2, parent=A, children_num=0
# ========================================================
# new node: C parent: A
# new node: B parent: C
# ========================================================
# id=2405144677344, item=A, count=4, parent=None, children_num=2
# id=2405144678112, item=B, count=2, parent=A, children_num=0
# id=2405144808128, item=C, count=2, parent=A, children_num=1
# id=2405144805872, item=B, count=2, parent=C, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2405144677344, item=A, count=4, parent=None, children_num=2
# id=2405144678112, item=B, count=2, parent=A, children_num=0
# id=2405144808128, item=C, count=2, parent=A, children_num=1
# id=2405144805872, item=B, count=2, parent=C, children_num=0
# @@@after remove bad node@@@
# id=2405144677344, item=A, count=4, parent=None, children_num=2
# id=2405144678112, item=B, count=2, parent=A, children_num=0
# id=2405144808128, item=C, count=2, parent=A, children_num=1
# id=2405144805872, item=B, count=2, parent=C, children_num=0
# 清空
# 不選 A , parent None
# 不選 B , parent A
# 選 B A
# 有前 {}
# 有後 {'B': 2}
# freq_item_set {'B': 2}
# 不選 C , parent A
# 不選 B , parent C
# 選 B C
# 有前 {}
# 有後 {'B': 2}
# freq_item_set {'B': 2}
# 選 C A
# 有前 {}
# 有後 {'C': 2}
# 不選 B , parent C
# 選 B C
# 有前 {'C': 2}
# 有後 {'C': 2, 'B': 2}
# freq_item_set {'C': 2, 'B': 2}
# freq_item_set {'C': 2}
# 選 A None
# 有前 {}
# 有後 {'A': 4}
# 不選 B , parent A
# 選 B A
# 有前 {'A': 4}
# 有後 {'A': 4, 'B': 2}
# freq_item_set {'A': 4, 'B': 2}
# 不選 C , parent A
# 不選 B , parent C
# 選 B C
# 有前 {'A': 4}
# 有後 {'A': 4, 'B': 2}
# freq_item_set {'A': 4, 'B': 2}
# 選 C A
# 有前 {'A': 4}
# 有後 {'A': 4, 'C': 2}
# 不選 B , parent C
# 選 B C
# 有前 {'A': 4, 'C': 2}
# 有後 {'A': 4, 'C': 2, 'B': 2}
# freq_item_set {'A': 4, 'C': 2, 'B': 2}
# freq_item_set {'A': 4, 'C': 2}
# freq_item_set {'A': 4}
# @@@我到底在幹嘛阿@@@
# ["{'E', 'B'}", 4]
# ["{'C', 'E', 'B'}", 2]
# ["{'C', 'E'}", 2]
# ["{'A', 'E', 'B'}", 4]
# ["{'A', 'C', 'E', 'B'}", 2]
# ["{'A', 'C', 'E'}", 2]
# ["{'A', 'E'}", 4]
# item C
# ('A',) 2
# @@@combination_dataset@@@ (('A',),)
# @@@counts@@@ (2,)
# new node: A parent: None
# ========================================================
# id=2405145501312, item=A, count=2, parent=None, children_num=0
# ========================================================
# @@@Combination FP tree@@@
# id=2405145501312, item=A, count=2, parent=None, children_num=0
# @@@after remove bad node@@@
# id=2405145501312, item=A, count=2, parent=None, children_num=0
# 清空
# 不選 A , parent None
# 選 A None
# 有前 {}
# 有後 {'A': 2}
# freq_item_set {'A': 2}
# @@@我到底在幹嘛阿@@@
# ["{'A', 'C'}", 2]
